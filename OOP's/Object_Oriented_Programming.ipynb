# %%
class Dog:
    pass

# %%
Dog()

# %%
Dog()

# %%
class Dog:
    # creating class attribute
    species = "cannies familiaris"
    
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
dog1 = Dog("teddy", "4")
dog2 = Dog("brutus", 5)

# %%
dog3 = Dog()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\anav\OneDrive\Desktop\pythonlearning\OOP's\Object_Oriented_Programming.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/anav/OneDrive/Desktop/pythonlearning/OOP%27s/Object_Oriented_Programming.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dog3 = Dog()
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'age'

# %%
print(dog1.name)
# Out:
# teddy

# %%
print(dog1.species)
# Out:
# cannies familiaris

# %%
dog1.age = 5
dog1.age
# Out:
# 5

# %%
dog1.species = "Cat"

# %%
dog1.species
# Out:
# 'Cat'

# %%
dog2.species
# Out:
# 'cannies familiaris'

# %% [markdown]
# ## Instance methods

# %% [markdown]
# **Instance methods** are functions that are defined inside a class and can only be called from an instance of that class. Just like .`__init__()`, an instance method’s first parameter is always `self.

# %%
class Dog():
    species = "Dog"
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def description(self):
        return f"Name of dog is: {self.name}"
    
    def speak(self, sound):
        print(sound)

# %%
dog1 = Dog("bruno", 12)
dog1.description()
dog1.speak("Bhow")
# Out:
# Bhow

# %%
dog1

# %%
names = list(("Bruno", "Teddy"))

# %%
names
# Out:
# ['Bruno', 'Teddy']

# %%
class Dog():
    species = "Dog"
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def description(self):
        return f"Name of dog is: {self.name}"
    
    def speak(self, sound):
        print(sound)
    
    def __str__(self):
        return f"{self.name} is {self.age} years old"

# %%
dog2 = Dog("miles", 4)
print(dog2)
# Out:
# miles is 4 years old

# %% [markdown]
# Methods like .`__init__()` and .`__str__()` are called dunder methods because they begin and end with double underscores. There are many dunder methods that you can use to customize classes in Python.

# %% [markdown]
# ## Accessing attributes

# %%
class Employee:
    """Common base class for all employees"""
    emp_count = 0

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.emp_count +=1
    
    def display_count(self):
        print(f"Total number of employees is {Employee.emp_count}")
    
    def display_Employee(self):
        print(f"{self.name}'s salary is {self.salary}")

# %%
employee1 = Employee("Zara", 2000)
employee2 = Employee("Manni", 5000)

# %%
Employee.emp_count
# Out:
# 2

# %%
employee1.display_count()
# Out:
# Total number of employees is 2

# %%
employee1.display_Employee()
employee2.display_Employee()
# Out:
# Zara's salary is 2000
# Manni's salary is 5000

# %%
employee1.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\anav\OneDrive\Desktop\pythonlearning\OOP's\Object_Oriented_Programming.ipynb Cell 29 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/anav/OneDrive/Desktop/pythonlearning/OOP%27s/Object_Oriented_Programming.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> employee1.age
#
# AttributeError: 'Employee' object has no attribute 'age'

# %%
employee1.age = 7

# %%
employee1.age
# Out:
# 7

# %%
employee1.age = 10

# %%
del employee1.age

# %% [markdown]
# Instead of using the normal statements to access attributes, you can use the following functions −
#
# - The **getattr(obj, name[, default])** − to access the attribute of object.
#
# - The **hasattr(obj,name)** − to check if an attribute exists or not.
#
# - The **setattr(obj,name,value)** − to set an attribute. If attribute does not exist, then it would be created.
#
# - The **delattr(obj, name)** − to delete an attribute.

# %%
employee1.age = 34

# %%
hasattr(employee1, "age")
# Out:
# True

# %%
getattr(employee1, "age")
# Out:
# 34

# %%
if hasattr(employee1, "age"):
    print(getattr(employee1, "age"))
# Out:
# 34

# %%
setattr(employee1, "age", 8)

# %%
delattr(employee1, "age")
delattr(employee2, "age")

# %%
print(hasattr(employee1, "age"))
print(hasattr(employee2, "age"))
# Out:
# False
# False

# %% [markdown]
# ## Built-in class attributes

# %% [markdown]
# Every Python class keeps following built-in attributes and they can be accessed using dot operator like any other attribute −
#
# - **`__dict__`** − Dictionary containing the class's namespace.
#
# - **`__doc__`** − Class documentation string or none, if undefined.
#
# - **`__name__`** − Class name.
#
# - **`__module__`** − Module name in which the class is defined. This attribute is `__main__` in interactive mode.
#
# - **`__bases__`** − A possibly empty tuple containing the base classes, in the order of their occurrence in the base class list.

# %%
Employee.__doc__
# Out:
# 'Common base class for all employees'

# %%
Employee.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__doc__': 'Common base class for all employees',
#               'emp_count': 0,
#               '__init__': <function __main__.Employee.__init__(self, name, salary)>,
#               'display_count': <function __main__.Employee.display_count(self)>,
#               'display_Employee': <function __main__.Employee.display_Employee(self)>,
#               '__dict__': <attribute '__dict__' of 'Employee' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Employee' objects>})

# %%
Employee.__name__
# Out:
# 'Employee'

# %%
Employee.__module__
# Out:
# '__main__'

# %%
Employee.__base__
# Out:
# object

# %% [markdown]
# # Inheritance

# %% [markdown]
# ## Inheritance

# %% [markdown]
# Inheritance is the ability to ‘inherit’ features or attributes from already written classes into newer classes we make. These features and attributes are defined data structures and the functions that we can perform with them a.k.a. Methods. This promotes code reusability which is considered one of the best industrial coding practices as it makes the codebase modular.
#
# In python inheritance, new class/es inherits from older class/es. The new class/es copy all functions and attributes of the older class into itself without rewriting the syntax in the new class/es. These new classes are also called derived classes, and old classes are called base classes.
#
# Child classes can override or extend the attributes and methods of parent classes. In other words, child classes inherit all of the parent’s attributes and methods but can also specify attributes and methods that are unique to themselves.
#
# Although the analogy isn’t perfect, you can think of object inheritance sort of like genetic inheritance.
#
# You may have inherited your hair color from your mother. It’s an attribute you were born with. Let’s say you decide to color your hair purple. Assuming your mother doesn’t have purple hair, you’ve just **overridden** the hair color attribute that you inherited from your mom.
#
# You also inherit, in a sense, your language from your parents. If your parents speak English, then you’ll also speak English. Now imagine you decide to learn a second language, like German. In this case you’ve **extended** your attributes because you’ve added an attribute that your parents don’t have.

# %% [markdown]
# ## Advantages of inheritance

# %% [markdown]
# - **Modular Codebase**: Increases modularity i.e. breaking down codebase into modules which makes it easier to understand. Here, each class that we define becomes a separate module that can be separately inherited by one or many classes.
#
# - **Code Reusability**: the child class copies all the attributes and methods of the parent class into its own class and use. This saves time and coding effort by not rewriting them thus following modularity paradigms.
# - **Less Development**: and Maintenance Costs: changes just need to be made in the base class, all derived classes will automatically follow.

# %% [markdown]
# ## Disadvantages of inheritance

# %% [markdown]
# - **Decreases the Execution Speed**: loading multiple classes because they are interdependent on each other
#
# - **Tightly Coupled Classes**: this means that even though parent classes can be executed independently, child classes cannot be executed without defining their parent classes.

# %% [markdown]
# ## Type of inheritance in python

# %% [markdown]
# ### Single-inheritance

# %% [markdown]
# Single Inheritance is the simplest form of inheritance where a single child class is derived from a single parent class. Due to its candid nature, it is also known as simple inheritance.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Parent:
  def func1(self):
    print("This is func 1 of parent")

class Child(Parent):
  def func2(self):
    print("this is func 2 of child")

child1 = Child()
child1.func1()
child1.func2()
# Out:
# This is func 1 of parent
# this is func 2 of child

# %%
parent1 = Parent()
parent1.func1()
parent1.func2()
# Out:
# This is func 1 of parent
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8d1cae6ef1af> in <module>
#       1 parent1 = Parent()
#       2 parent1.func1()
# ----> 3 parent1.func2()
#
# AttributeError: 'Parent' object has no attribute 'func2'

# %% [markdown]
# ###Multiple-inheritance

# %% [markdown]
# In multiple inheritance, a single child class is inherited from two or more parent classes. This means the child class has access to all the methods and attributes of all the parent classes.
#
# However, if two parents have the same “named” methods, the child class performs the method of the first parent in order of reference. To get a better understanding of which class’s methods shall be executed first, we can use the **Method Resolution Order** function (mro). This tells the order in which the child class is interpreted to visit the other classes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Parent1:
  def func1(self):
    print("You are in func1 of Parent1")


class Parent2:
  def func2(self):
    print("You are in func2 of Parent2")


class Parent3:
  def func2(self):
    print("You are in func2 of Parent3")


class Child(Parent1,  Parent3, Parent2):
  def func3(self):
    print("You are in func3 of Child")

# %%
child1 = Child()
child1.func1()
child1.func2()
child1.func3()
# Out:
# You are in func1 of Parent1
# You are in func2 of Parent3
# You are in func3 of Child

# %% [markdown]
# #### Method Resolution Order(MRO)

# %% [markdown]
# MRO is the order by which Python looks for a method or attribute. First, the method or attribute is searched within a class, and then it follows the order we specified while inheriting.
#
# This order is also called the **Linearization** of a class, and a set of rules is called MRO (Method Resolution Order). **The MRO plays an essential role in multiple inheritances as a single method may found in multiple parent classes.**
#
# In multiple inheritance, the following search order is followed.
#
# - First, it searches in the current parent class if not available, then searches in the parents class specified while inheriting (that is left to right.)
# - We can get the MRO of a class. For this purpose, we can use either the mro attribute or the `mro`() method.

# %%
print(Child.__mro__)
# Out:
# (<class '__main__.Child'>, <class '__main__.Parent1'>, <class '__main__.Parent3'>, <class '__main__.Parent2'>, <class 'object'>)

# %% [markdown]
# ### Multilevel-inheritance

# %% [markdown]
# In multilevel inheritance, we go beyond just a parent-child relation. We introduce grandchildren, great-grandchildren, grandparents, etc. Basically, till now we saw only two levels of inheritance with a superior parent class/es and a derived class/es, but here we can have multiple levels where the parent class/es itself is derived from another class/es.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class GrandParent:
  def func1(self):
    print("You are in GrandParent class")


class Parent(GrandParent):
  def func2(self):
    print("You are in Parent class")


class Child(Parent):
  def func3(self):
    print("You are in Child class")

# %%
child = Child()

child.func1()
child.func2()
child.func3()
# Out:
# You are in GrandParent class
# You are in Parent class
# You are in Child class

# %% [markdown]
# ### Hierarchical-inheritance

# %% [markdown]
# Hierarchical Inheritance is the right opposite of multiple inheritance. This means that there are multiple derived child classes from a single parent class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Parent:
  def func1(self):
    print("In func1 of Parent class")


class Child1(Parent):
  def func2(self):
    print("In func2 of Child1 class")


class Child2(Parent):
  def func3(self):
    print("In func3 of Child2 class")

# %%
child1 = Child1()
child2 = Child2()

child1.func1()
child1.func2()

child2.func1()
child2.func3()
# Out:
# In func1 of Parent class
# In func2 of Child1 class
# In func1 of Parent class
# In func3 of Child2 class

# %% [markdown]
# ### Hybrid-inheritance

# %% [markdown]
# Hybrid Inheritance is the mixture of two or more different types of inheritance. Here we can have many to many relations between parent classes and child classes with multiple levels.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Parent1:
  def func1(self):
    print("This is func1 of Parent1")


class Parent2:
  def func2(self):
    print("This is func2 of Parent2")


class Child1(Parent1):
  def func3(self):
    print("This is func3 of Child1")


class Child2(Child1, Parent2):
  def func4(self):
    print("This is func4 of Child2")

# %%
child2 = Child2()
child1 = Child1()

child2.func1()
child2.func2()
child2.func3()
child2.func4()

child1.func1()
child1.func3()
# Out:
# This is func1 of Parent1
# This is func2 of Parent2
# This is func3 of Child1
# This is func4 of Child2
# This is func1 of Parent1
# This is func3 of Child1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Special functions in python inheritance

# %% [markdown]
# ### Super functions

# %% [markdown]
# In child class, we can refer to parent class by using the `super()` function. The super function returns a temporary object of the parent class that allows us to call a parent class method inside a child class method.
#
# Benefits of using the `super()` function.
#
# - We are not required to remember or specify the parent class name to access its methods.
# - We can use the `super()` function in both single and multiple inheritances.
# - The `super()` function support code reusability as there is no need to write the entire function

# %%
class Company:
  def company_name(self):
    return "Google"


class Employee(Company):
  def info(self):
    cname = super().company_name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# Google

# %%
class Company:
  def company_name(self):
    return "Google"


class Country:
  def country_name(self):
    return "India"


class Employee(Company, Country):
  def info(self):
    cname = super().company_name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# Google

# %%
class Company:
  def company_name(self):
    return "Google"


class Country:
  def country_name(self):
    return "India"


class Employee(Company, Country):
  def info(self):
    cname = super().country_name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# India

# %%
class Company:
  def name(self):
    return "Google"


class Country:
  def name(self):
    return "India"


class Employee(Company, Country):
  def info(self):
    cname = super().name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# Google

# %%
class Company:
  def name(self):
    return "Google"


class Country:
  def name(self):
    return "India"


class Employee(Country, Company):
  def info(self):
    cname = super().name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# India

# %%
class Company:
  def name(self):
    return "Google"


class Country(Company):
  def name(self):
    return "India"


class Employee(Country):
  def info(self):
    cname = super().name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# India

# %%
class Company:
  def name(self):
    return "Google"


class Country(Company):
  def name1(self):
    return "India"


class Employee(Country):
  def info(self):
    cname = super().name()
    print(cname)


employee1 = Employee()
employee1.info()
# Out:
# Google

# %% [markdown]
# ### issubclass()

# %% [markdown]
# In Python, we can verify whether a particular class is a subclass of another class. For this purpose, we can use Python built-in function `issubclass()`. This function returns `True` if the given class is the subclass of the specified class. Otherwise, it returns `False`.
# **Syntax**
#
# `issubclass(class, classinfo)`
#
# Where,
#
# - `class`: class to be checked.
# - `classinfo`: a class, type, or a tuple of classes or data types.

# %%
class Company:
  def name(self):
    return "Google"


class Employee(Company):
  pass


class Country:
  pass

# %%
print(issubclass(Country, Company))
print(issubclass(Country, Employee))
print(issubclass(Employee, Company))
print(issubclass(Employee, (Country, Company)))
# Out:
# False
# False
# True
# True

# %% [markdown]
# ## Method override

# %% [markdown]
# In inheritance, all members available in the parent class are by default available in the child class. If the child class does not satisfy with parent class implementation, then the child class is allowed to redefine that method by **extending** additional functions in the child class. This concept is called method **overriding**.
#
# When a child class method has the same name, same parameters, and same return type as a method in its superclass, then the method in the child is said to **override** the method in the parent class.`

# %%
class Vehicle:
  def max_speed(self):
    print("Maximum speed is 100 kph")


class Car(Vehicle):
  def max_speed(self):
    super().max_speed()
    print("Maximum speed is 200 kph")

car1 = Car()
car1.max_speed()
# Out:
# Maximum speed is 100 kph
# Maximum speed is 200 kph
